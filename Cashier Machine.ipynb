# %% [markdown]
# # Cashier Machine
# ## By Elen Jaxx

# %% [markdown]
# This is a project for medium-begginers in python. It consists in creating a code that would read an inventory and iterate through it with the user's input. I decided to add more fancy stuff than the examples I've been studying have, so it feels more real and useful. The structure can be summarized as it follows:
#
# > **dictionaries**: This program needs two dictionaries to work: the stock from the store and the shopping list from the client.
# It is important to leave them open at the beggining.
#
# > **User**: defines the client. This can open the path to a membership area or registration. I will study that option further.
#
# > **screen**: it reads the inventory of the store. For that purpose, I created a txt version, thus the data is external to the code (this way, the store can write a simple list, they don't need to use python).
#
# > **Shopping**: this part of the code needs loops to recieve input from the user. We will ask them if they want to shop,
# if so what items, which quantity and when are they ready to stop. Later, the program will print an invoice.
#
# >> **discounts**: I added this part to work with a simple discount. If the total is equal or greater than 10, a 10% discount is applied, but only if they have the discount code. This part of the code can be expanded to more types of discounts.
#
# >>> Discount code: *JAXX*
#
# *Please note: I decided to divide the code in functions so I can have a clear vision and work on it sepparately. This is not necessary at all, since the program doesn't repeat actions further from some loops. However, it feels easy for me, and it might work for you too.
#
# Other sepparations of the code are marked with "###########################*

# %%
#Open blank dictionaries to work with them throughout the code.
stockDict = {}
shoplistDict = {}

# %%
#Define the account (this code can be enhanced)
def user():
    name = input("Please, write your account name:")
    message = f"Good day, {name}"
    #This part of the code is to make it more user friendly. It prints some stars to sepparate the info on the screen.
    lenmessage = len(message) #it reads the length of good day, {name}
    print("*"*lenmessage) #prints said lenght with stars
    print(message)
    print("*"*lenmessage)

# %%
#Stablish the information on the screen. This part will read the txt archive with the stock and print it to the user.
def screen():
    Message2 = "\n****Our products today are****" #remember, \n jumps, just like in html
    lenMessage2 = len(Message2)
    print(Message2)
    
    #define the stock (open the txt)
    my_file=open("stock_cashier.txt")
    file_line=my_file.readline() #this avoids to read the first line (product-value)
    stock=my_file.readlines()
    my_file.close
    
    #read the stock
    for item in stock:
        item_name=item.split()[0] #this allows you to read both columns and sepparate them in name and price for the list.
        item_price=item.split()[1]
        print(f"{item_name}: {item_price}") #with the f function you can print them both to the screen, quick and easy.
        # now you can update your blank diccionary, for the txt is finally readable.
        stockDict.update({item_name: float(item_price)})
                        #remember to format price to float, otherwise it won't sum and multiply later.
    print ("\n")
    print("*"*lenMessage2) # remember to use the correct indent, if those prints were just underneath "stock.." 
                           # you would have had stars for every item.

# %%
# Allow shopping. This is a battlefield for loops. 

#Careful with the indents, double= and capital letters.
#This couldn't be divided in more functions because we need to call actions at different times. 
  #Thus, there are divisions for better visualization of the code using "####" and closes with "/".
    
def shop():
    shop = True
    while shop:
        print ("\n") #for clean output
        create_list = input ("Would you like to buy something? > Click 'y' to start or 'n' to stop: ")
        #################################################################################
        #user decides to shop or exit
        #################################################################################
        if create_list == "y":
            #############################################################
            #user shops
            #############################################################
            shop_loop = True
            while shop_loop:
                add_item = input ("Which product would you like? / Press 'x' when you are finished: ")
                ###############################
                #adding items
                ###############################
                if add_item.title() in stockDict: #title reads upper or lower and this structure assures the item is in stock.
                    add_q = int(input("How many?: "))
                    shoplistDict.update({add_item:{"quantity":add_q,
                                              "subtotal":float(stockDict[add_item.title()]*add_q)}})
                                        #this creates nested dictionaries. Format float to work with the data.
                    print (shoplistDict)
                    print ("\n")

                elif add_item == 'x':
                    print ("...reading your shopping list...")
                    print ("\n")
                    
                    ##################
                    #Invoice
                    ##################
                    print ("Product    Quantity    Subtotal") #4 spaces for the funsies
                    total = 0
                    for item in shoplistDict:
                        print (f"{item}        {shoplistDict[item]['quantity']}        {shoplistDict[item]['subtotal']}")
                               #8 spaces so it more or less prints equaly
                               # this could be enhanced for better visuals but i don't know how.
                               #please remember, you are working with a nested dictionary, that is why you need
                                 #[item] followed with ['quantity']['subtotal'] as you created them updating the shoplistDict.
                        print ("\n")
                        total = shoplistDict[item]['subtotal'] + total
                            #this way, total variable is not zero, for it sums itself to every subtotal.
                    #please be aware of the indent in this one!!
                    print (f"Total: {total} euros")
                    
                    #####
                    #discounts 
                    #>> code: 'JAXX'
                    #####
                    if total >= 10:
                        discounts = True
                        while discounts:
                            discount = input ("Congrats! You can use a discount. Do you have the code? >Write 'y' or 'n': ")
                            if discount == "y":
                                code = input ("Please, enter your code: ")
                                if code == 'JAXX':
                                    print ("Correct code")
                                    discount = total * (10/100)
                                    total = total - discount
                                    print (f" Final payment: {total} euros")
                                    break
                                else:
                                    print ("I can't read the code. Please, try again: ")
                            elif descuento == "n":
                                print (f" Final payment: {total} euros")
                                descuentos = False
                                break
                            else:
                                print ("That is not a valid option. Please, try again: ")
                    #####
                    #/discounts
                    #####
                               
                    print ("\n")
                    print ("Thank you so much, see you soon!")
                    shop_loop = False
                    shop = False
                    break
                    ##################
                    #/Invoice
                    ##################
                               
                else: 
                    print ("""This product is not available
                    or you have written it differently. 
                    Please, try again: """)
                ###############################
                #/adding items
                ###############################
                               
            #############################################################
            #user shops
            #############################################################
                               
        elif crete_list == 'n':
            print ("See you next time then!")
            shop = False
            break
        else: 
            print ("Please, select a correct option:")
            
        #################################################################################
        #/user decides to shop or exit
        #################################################################################

# %%
#now, call all the different functions. I decided to group them in one to create the definitive, with the program name.
def Cashier_Machine():
    user()
    screen()
    shop()

# %%
#ejecute the cashier
Cashier_Machine()
# Out:
# Please, write your account name:Elen Jaxx
# *******************
# Good day, Elen Jaxx
# *******************
#
# ****Our products today are****
# Milk: 2
# Sugar: 0.5
# Coffee: 1.2
# Chocolate: 1.2
#
#
# *******************************
#
#
# Would you like to buy something? > Click 'y' to start or 'n' to stop: y
# Which product would you like? / Press 'x' when you are finished: milk
# How many?: 5
# {'milk': {'quantity': 5, 'subtotal': 10.0}}
#
#
# Which product would you like? / Press 'x' when you are finished: sugar
# How many?: 2
# {'milk': {'quantity': 5, 'subtotal': 10.0}, 'sugar': {'quantity': 2, 'subtotal': 1.0}}
#
#
# Which product would you like? / Press 'x' when you are finished: x
# ...reading your shopping list...
#
#
# Product    Quantity    Subtotal
# milk        5        10.0
#
#
# sugar        2        1.0
#
#
# Total: 11.0 euros
# Congrats! You can use a discount. Do you have the code? >Write 'y' or 'n': y
# Please, enter your code: JAXX
# Correct code
# ...
