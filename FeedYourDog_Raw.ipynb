# %% [markdown]
# # FEED YOUR DOG
#
# ## By Elen Jaxx
#
#
# This program meassures how much dog food your pet should be eating, regarding their age, activity and weight.
#
# It has the option of meassuring in kilos and libras.
#
# I have contrasted the information from [kiwoko.com](kiwoko.com) and [dog.ie.](dog.ie)
#
# Reference data: 1 gram=0,35 onz // 1kg = 0,45lb.
#
# **Interesting updates:**
#
# 1. How many grams can the food container hold;
# 2. GUI in Tkinter;
# 3. Translate into English.

# %%
def kg ():
    peso = int(input("Indica el peso de tu mascota en kilogramos:")) 

    if peso <= 3:
        gramos1 = 50
    elif peso > 3 and peso <= 10:
        gramos1 = 90
    elif peso > 10 and peso <= 20:
        gramos1 = 190
    elif peso > 20 and peso <= 40:
        gramos1 = 500
    elif peso > 40 and peso <= 50:
        gramos1 = 590

    edad = input ("""Indica el rango de edad de tu mascota:
                A. Menos de 4 meses.
                B. Entre 4 meses y un año.
                C. Más de un año.
                """)
    if edad == "A":
        gramos2 = gramos1+100
        tomas = 4
    elif edad == "B":
        gramos2 = gramos1+50
        tomas = 3
    elif edad == "C":
        gramos2 = gramos1
        tomas = 2
    else: 
        print ("Introduzca una opción válida")
             
    actividad = input ("""Escoge el nivel de actividad de tu mascota:
                    D. Debe perder peso, se mueve muy poco;
                    E. El tiempo de paseo diario no es más de hora y media y juega un poco;
                    F. El tiempo de paseo diario es de dos horas o más y juega mucho;
                    G. Mi mascota trabaja de pastor / tira de trineos o carros / es de rescate o ejército.
                    """)
           
    if actividad == "D":
        print (f"Debe comer {gramos2} gramos en {tomas} tomas")
    elif actividad == "E":
        print (f"Debe comer {gramos2+50} gramos en {tomas} tomas")
    elif actividad == "F":
        print (f"Debe comer {gramos2+100} gramos en {tomas} tomas")
    elif actividad == "G":
        print (f"Debe comer {gramos2+150} gramos en {tomas} tomas")
    else:
        print ("Introduzca una opción válida")

# %%
def lb ():
    peso = int(input("Indica el peso de tu mascota en libras:")) 
    onzas1=0
    onzas2=0
    tomas=0
    if peso <= 3:
        onzas1 = 50*0.35
    elif peso > 3 and peso <= 10:
        onzas1 = 90*0.35
    elif peso > 10 and peso <= 20:
        onzas1 = 190*0.35
    elif peso > 20 and peso <= 40:
        onzas1 = 500*0.35
    elif peso > 40 and peso <= 50:
        onzas1 = 590*0.35

    edad = input ("""Indica el rango de edad de tu mascota:
                A. Menos de 4 meses.
                B. Entre 4 meses y un año.
                C. Más de un año.
                """)
    if edad == "A":
        onzas2 = onzas1+(100*0.35)
        tomas = 4
    elif edad == "B":
        onzas2 = onzas1+(50*0.35)
        tomas = 3
    elif edad == "C":
        onzas2 = onzas1
        tomas = 2
    else: 
        print ("Introduzca una opción válida")
             
    actividad = input ("""Escoge el nivel de actividad de tu mascota:
                    D. Debe perder peso, se mueve muy poco;
                    E. El tiempo de paseo diario no es más de hora y media y juega un poco;
                    F. El tiempo de paseo diario es de dos horas o más y juega mucho;
                    G. Mi mascota trabaja de pastor / tira de trineos o carros / es de rescate o ejército.
                    """)
           
    if actividad == "D":
        print (f"Debe comer {onzas2} onzas en {tomas} tomas")
    elif actividad == "E":
        print (f"Debe comer {onzas2+(50*0.35)} onzas en {tomas} tomas")
    elif actividad == "F":
        print (f"Debe comer {onzas2+(100*0.35)} onzas en {tomas} tomas")
    elif actividad == "G":
        print (f"Debe comer {onzas2+(150*0.35)} onzas en {tomas} tomas")
    else:
        print ("Introduzca una opción válida")

# %%
def interaction ():
    medida = input("""¿Qué unidad de medida utilizas?
            1. Kilos y gramos
            2. Libras y onzas
            """)
    if medida == "1":
        kg()
    elif medida == "2":
        lb()
    else:
        print ("Por favor, introduce una opción válida")

# %%
interaction()
# Out:
# ¿Qué unidad de medida utilizas?
#             1. Kilos y gramos
#             2. Libras y onzas
#              1
# Indica el peso de tu mascota en kilogramos: 42
# Indica el rango de edad de tu mascota:
#                 A. Menos de 4 meses.
#                 B. Entre 4 meses y un año.
#                 C. Más de un año.
#                  C
# Escoge el nivel de actividad de tu mascota:
#                     D. Debe perder peso, se mueve muy poco;
#                     E. El tiempo de paseo diario no es más de hora y media y juega un poco;
#                     F. El tiempo de paseo diario es de dos horas o más y juega mucho;
#                     G. Mi mascota trabaja de pastor / tira de trineos o carros / es de rescate o ejército.
#                      E
# Debe comer 640 gramos en 2 tomas
